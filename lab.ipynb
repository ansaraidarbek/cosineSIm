# %%
from elasticsearch import Elasticsearch

es = Elasticsearch("http://localhost:9200")
es.info().body
# Out:
# {'name': '1d81598a1420',
#  'cluster_name': 'docker-cluster',
#  'cluster_uuid': 'bll6FNb4TT2czEtGbIlUVg',
#  'version': {'number': '8.6.1',
#   'build_flavor': 'default',
#   'build_type': 'docker',
#   'build_hash': '180c9830da956993e59e2cd70eb32b5e383ea42c',
#   'build_date': '2023-01-24T21:35:11.506992272Z',
#   'build_snapshot': False,
#   'lucene_version': '9.4.2',
#   'minimum_wire_compatibility_version': '7.17.0',
#   'minimum_index_compatibility_version': '7.0.0'},
#  'tagline': 'You Know, for Search'}

# %%
import pandas as pd

df = pd.read_csv('documents.csv')

# %% [markdown]
# Without stemming

# %%
index_name = 'without_stem'
mappings = {
    'properties': {
        'text': {
            'type': 'text',
            'analyzer': 'white'
        }
    }
}

settings = {
    'analysis' : {
        'analyzer' : {
            'white' : {
                'tokenizer' : 'whitespace'
            }
        }
    }
}

if es.indices.exists(index=index_name):
    es.indices.delete(index=index_name)
es.indices.create(index=index_name, settings=settings, mappings=mappings)
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'without_stem'})

# %%
def check_analyzer(analyzer, text):
    
    body = analyzer
    body['text'] = text
    
    tokens = es.indices.analyze(index=index_name, body=body)['tokens']
    tokens = [token_info['token'] for token_info in tokens]
    return tokens

text = 'did it   fina  lly'
analyzer = {
    'analyzer': 'white'
}

check_analyzer(analyzer, text)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_13808\156965612.py:6: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   tokens = es.indices.analyze(index=index_name, body=body)['tokens']
# ['did', 'it', 'fina', 'lly']

# %%
from tqdm import tqdm
from time import time
from elasticsearch.helpers import bulk, parallel_bulk
def create_es_action(index, doc_id, document):
    return {
        '_index': index,
        '_id': doc_id,
        '_source': document
    }


def es_action_generator(df):
    for doc_id, row in tqdm(df.iterrows(), total=df.shape[0]):
        doc = {
            'text': row['text_right'],
        }
        yield create_es_action(index_name, row['id_right'], doc)


start = time()
for ok, result in parallel_bulk(es, es_action_generator(df), queue_size=4, thread_count=4, chunk_size=1000):
    if not ok:
        print(result)
stop = time()

print('Indexing time:', stop-start)
# Out:
# 100%|██████████| 369721/369721 [01:13<00:00, 5049.03it/s]
# Indexing time: 76.13157105445862

# %%
es.indices.refresh(index=index_name)
es.cat.count(index=index_name, format='json')
# Out:
# ListApiResponse([{'epoch': '1680247458', 'timestamp': '07:24:18', 'count': '369721'}])

# %%
def pretty_print_result(search_result, fields=[]):
    res = search_result['hits']
    print(f'Total documents: {res["total"]["value"]}')
    for hit in res['hits']:
        print(f'Doc {hit["_id"]}, score is {hit["_score"]}')
        for field in fields:
            print(f'{field}: {hit["_source"][field]}')
    
def search(query, *args):
    return pretty_print_result(es.search(index=index_name, query=query, size=20), args)

def get_doc_by_id(doc_id):
    return es.get(index=index_name, id=doc_id)['_source']

# customized
def get_results(search_result):
    res = search_result['hits']
    for hit in res['hits']:        
        return hit['_id'], hit['_score']


def search_results(query_id, query):
    res = es.search(index=index_name, query=query, size=20)['hits']
    ret = []
    for rank, hit in enumerate(res['hits']):
        ret.append((str(query_id), str(hit['_id']), hit['_score'], rank))
    return ret

# %%
test_queries = pd.read_csv('queries.csv')
test_queries.head()
# Out:
#    id_left                           text_left
# 0   158491       southern methodist university
# 1     5728                             halakha
# 2    13554  chief justice of the united states
# 3    32674                         patsy cline
# 4   406391                      dierks bentley

# %%
import ir_measures
def make_query(text):
    return {
        'bool': {
            'must': {
                'match': {
                    'text': text
                }
            }
        }
    }

def generate_run(test_queries, save_to_file=False, filename=None):
    if save_to_file:
        f = open(filename, 'w')
    
    run = []
    for i, row in test_queries.iterrows():
        for res in search_results(row['id_left'], make_query(row['text_left'])):
            if(res[3]<21):
                run.append(ir_measures.ScoredDoc(res[0], res[1], res[2]))
                if save_to_file:
                    f.write(f'{res[0]} Q0 {res[1]} {res[3]} {res[2]} BM25\n')
    
    if save_to_file:
        f.close()

    return run

def print_scores(run, total=-1):
    if total > len(run) or total==-1:
        total = len(run)
    for i in range(total):
        print(run[i])

run = generate_run(test_queries, True, 'search_without_stem.res')
print_scores(run, 10)
# Out:
# ScoredDoc(query_id='158491', doc_id='1880296', score=17.35782)
# ScoredDoc(query_id='158491', doc_id='2261272', score=17.199305)
# ScoredDoc(query_id='158491', doc_id='607552', score=17.118353)
# ScoredDoc(query_id='158491', doc_id='1957435', score=16.929768)
# ScoredDoc(query_id='158491', doc_id='625257', score=16.877832)
# ScoredDoc(query_id='158491', doc_id='635537', score=16.80612)
# ScoredDoc(query_id='158491', doc_id='1774491', score=16.570059)
# ScoredDoc(query_id='158491', doc_id='663828', score=16.55547)
# ScoredDoc(query_id='158491', doc_id='158491', score=16.063732)
# ScoredDoc(query_id='158491', doc_id='1956922', score=15.829921)

# %% [markdown]
# Stemming

# %%
index_name = 'with_stem'
mappings = {
    'properties': {
        'text': {
            'type': 'text',
            'analyzer': 'porter_stemmer'
        }
    }
}

settings = {
    'analysis' : {
        'analyzer' : {
            'porter_stemmer' : {
                'tokenizer' : 'whitespace',
                'filter' : ['porter_stem']
            }
        },
        'filter' : {
            'porter_stem' : {
                'type' : 'porter_stem',
                'language' : 'English'
            }
        }
    }
}

if es.indices.exists(index=index_name):
    es.indices.delete(index=index_name)
es.indices.create(index=index_name, settings=settings, mappings=mappings)
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'with_stem'})

# %%
text = 'using playing ate agoing'
analyzer = {
    'analyzer': 'porter_stemmer'
}

check_analyzer(analyzer, text)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10296\156965612.py:6: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   tokens = es.indices.analyze(index=index_name, body=body)['tokens']
# ['us', 'plai', 'at', 'ago']

# %%
start = time()
for ok, result in parallel_bulk(es, es_action_generator(df), queue_size=4, thread_count=4, chunk_size=1000):
    if not ok:
        print(result)
stop = time()

print('Indexing time:', stop-start)
# Out:
# 100%|██████████| 369721/369721 [02:05<00:00, 2952.31it/s]
# ---------------------------------------------------------------------------
# ConnectionTimeout                         Traceback (most recent call last)
# d:\Учеба\Назарбаев Университет\Masters\masters1Year\secondSem\InfoRetrieval\labs\lab.ipynb Cell 14 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/%D0%A3%D1%87%D0%B5%D0%B1%D0%B0/%D0%9D%D0%B0%D0%B7%D0%B0%D1%80%D0%B1%D0%B0%D0%B5%D0%B2%20%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/Masters/masters1Year/secondSem/InfoRetrieval/labs/lab.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> start = time()
# ----> <a href='vscode-notebook-cell:/d%3A/%D0%A3%D1%87%D0%B5%D0%B1%D0%B0/%D0%9D%D0%B0%D0%B7%D0%B0%D1%80%D0%B1%D0%B0%D0%B5%D0%B2%20%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/Masters/masters1Year/secondSem/InfoRetrieval/labs/lab.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> for ok, result in parallel_bulk(es, es_action_generator(df), queue_size=4, thread_count=4, chunk_size=1000):
#       <a href='vscode-notebook-cell:/d%3A/%D0%A3%D1%87%D0%B5%D0%B1%D0%B0/%D0%9D%D0%B0%D0%B7%D0%B0%D1%80%D0%B1%D0%B0%D0%B5%D0%B2%20%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/Masters/masters1Year/secondSem/InfoRetrieval/labs/lab.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a>     if not ok:
#       <a href='vscode-notebook-cell:/d%3A/%D0%A3%D1%87%D0%B5%D0%B1%D0%B0/%D0%9D%D0%B0%D0%B7%D0%B0%D1%80%D0%B1%D0%B0%D0%B5%D0%B2%20%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/Masters/masters1Year/secondSem/InfoRetrieval/labs/lab.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a>         print(result)
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\elasticsearch\helpers\actions.py:598, in parallel_bulk(client, actions, thread_count, chunk_size, max_chunk_bytes, queue_size, expand_action_callback, ignore_status, *args, **kwargs)
#     595 pool = BlockingPool(thread_count)
#     597 try:
# --> 598     for result in pool.imap(
#     599         lambda bulk_chunk: list(
#     600             _process_bulk_chunk(
#     601                 client,
#     602                 bulk_chunk[1],
#     603                 bulk_chunk[0],
#     604                 ignore_status=ignore_status,  # type: ignore[misc]
#     605                 *args,
#     606                 **kwargs,
#     607             )
#     608         ),
#     609         _chunk_actions(expanded_actions, chunk_size, max_chunk_bytes, serializer),
#     610     ):
#     611         yield from result
#     613 finally:
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\multiprocessing\pool.py:870, in IMapIterator.next(self, timeout)
#     868 if success:
#     869     return value
# --> 870 raise value
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\multiprocessing\pool.py:125, in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123 job, i, func, args, kwds = task
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#     127     if wrap_exception and func is not _helper_reraises_exception:
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\elasticsearch\helpers\actions.py:599, in parallel_bulk.<locals>.<lambda>(bulk_chunk)
#     595 pool = BlockingPool(thread_count)
#     597 try:
#     598     for result in pool.imap(
# --> 599         lambda bulk_chunk: list(
#     600             _process_bulk_chunk(
#     601                 client,
#     602                 bulk_chunk[1],
#     603                 bulk_chunk[0],
#     604                 ignore_status=ignore_status,  # type: ignore[misc]
#     605                 *args,
#     606                 **kwargs,
#     607             )
#     608         ),
#     609         _chunk_actions(expanded_actions, chunk_size, max_chunk_bytes, serializer),
#     610     ):
#     611         yield from result
#     613 finally:
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\elasticsearch\helpers\actions.py:339, in _process_bulk_chunk(client, bulk_actions, bulk_data, raise_on_exception, raise_on_error, ignore_status, *args, **kwargs)
#     335     ignore_status = (ignore_status,)
#     337 try:
#     338     # send the actual request
# --> 339     resp = client.bulk(*args, operations=bulk_actions, **kwargs)  # type: ignore[arg-type]
#     340 except ApiError as e:
#     341     gen = _process_bulk_chunk_error(
#     342         error=e,
#     343         bulk_data=bulk_data,
#    (...)
#     346         raise_on_error=raise_on_error,
#     347     )
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\elasticsearch\_sync\client\utils.py:414, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     411         except KeyError:
#     412             pass
# --> 414 return api(*args, **kwargs)
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\elasticsearch\_sync\client\__init__.py:693, in Elasticsearch.bulk(self, operations, index, error_trace, filter_path, human, pipeline, pretty, refresh, require_alias, routing, source, source_excludes, source_includes, timeout, wait_for_active_shards)
#     688 __body = operations
#     689 __headers = {
#     690     "accept": "application/json",
#     691     "content-type": "application/x-ndjson",
#     692 }
# --> 693 return self.perform_request(  # type: ignore[return-value]
#     694     "PUT", __path, params=__query, headers=__headers, body=__body
#     695 )
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\elasticsearch\_sync\client\_base.py:286, in BaseClient.perform_request(self, method, path, params, headers, body)
#     283 else:
#     284     target = path
# --> 286 meta, resp_body = self.transport.perform_request(
#     287     method,
#     288     target,
#     289     headers=request_headers,
#     290     body=body,
#     291     request_timeout=self._request_timeout,
#     292     max_retries=self._max_retries,
#     293     retry_on_status=self._retry_on_status,
#     294     retry_on_timeout=self._retry_on_timeout,
#     295     client_meta=self._client_meta,
#     296 )
#     298 # HEAD with a 404 is returned as a normal response
#     299 # since this is used as an 'exists' functionality.
#     300 if not (method == "HEAD" and meta.status == 404) and (
#     301     not 200 <= meta.status < 299
#     302     and (
#    (...)
#     306     )
#     307 ):
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\elastic_transport\_transport.py:329, in Transport.perform_request(self, method, target, body, headers, max_retries, retry_on_status, retry_on_timeout, request_timeout, client_meta)
#     327 start_time = time.time()
#     328 try:
# --> 329     meta, raw_data = node.perform_request(
#     330         method,
#     331         target,
#     332         body=request_body,
#     333         headers=request_headers,
#     334         request_timeout=request_timeout,
#     335     )
#     336     _logger.info(
#     337         "%s %s%s [status:%s duration:%.3fs]"
#     338         % (
#    (...)
#     344         )
#     345     )
#     347     if method != "HEAD":
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\elastic_transport\_node\_http_urllib3.py:199, in Urllib3HttpNode.perform_request(self, method, target, body, headers, request_timeout)
#     191         err = ConnectionError(str(e), errors=(e,))
#     192     self._log_request(
#     193         method=method,
#     194         target=target,
#    (...)
#     197         exception=err,
#     198     )
# --> 199     raise err from None
#     201 meta = ApiResponseMeta(
#     202     node=self.config,
#     203     duration=duration,
#    (...)
#     206     headers=response_headers,
#     207 )
#     208 self._log_request(
#     209     method=method,
#     210     target=target,
#    (...)
#     214     response=data,
#     215 )
#
# ConnectionTimeout: Connection timed out

# %%
es.indices.refresh(index=index_name)
es.cat.count(index=index_name, format='json')
# Out:
# ListApiResponse([{'epoch': '1679477778', 'timestamp': '09:36:18', 'count': '369721'}])

# %%
run = generate_run(test_queries=test_queries, save_to_file=True, filename='search_with_stem.res')
print_scores(run, 20)
# Out:
# ScoredDoc(query_id='158491', doc_id='1880296', score=17.132378)
# ScoredDoc(query_id='158491', doc_id='2261272', score=16.981)
# ScoredDoc(query_id='158491', doc_id='607552', score=16.919212)
# ScoredDoc(query_id='158491', doc_id='625257', score=16.701923)
# ScoredDoc(query_id='158491', doc_id='1957435', score=16.695692)
# ScoredDoc(query_id='158491', doc_id='635537', score=16.567877)
# ScoredDoc(query_id='158491', doc_id='663828', score=16.392046)
# ScoredDoc(query_id='158491', doc_id='1774491', score=16.352182)
# ScoredDoc(query_id='158491', doc_id='158491', score=16.30711)
# ScoredDoc(query_id='158491', doc_id='1956922', score=15.618095)
# ScoredDoc(query_id='158491', doc_id='1180246', score=15.388653)
# ScoredDoc(query_id='158491', doc_id='1170039', score=15.346355)
# ScoredDoc(query_id='158491', doc_id='360918', score=15.305798)
# ScoredDoc(query_id='158491', doc_id='589549', score=15.305798)
# ScoredDoc(query_id='158491', doc_id='945068', score=15.255717)
# ScoredDoc(query_id='158491', doc_id='685181', score=15.237276)
# ScoredDoc(query_id='158491', doc_id='2411344', score=15.013994)
# ScoredDoc(query_id='158491', doc_id='1158969', score=15.013994)
# ScoredDoc(query_id='158491', doc_id='1093529', score=15.013994)
# ScoredDoc(query_id='158491', doc_id='742912', score=14.931139)

# %%
from ir_measures import *
run = ir_measures.read_trec_run('BM25.res')
qrels = ir_measures.read_trec_qrels('qrels')

ir_measures.calc_aggregate([P@10, P@20, AP], qrels, run)
# Out:
# {P@20: 0.09499999999999999, P@10: 0.1319999999999999, AP: 0.11196168401599797}

# %%
run = ir_measures.read_trec_run('search_without_stem.res')

qrels = ir_measures.read_trec_qrels('qrels')

ir_measures.calc_aggregate([P@10, P@20, AP], qrels, run)
# Out:
# {P@20: 0.14800000000000005, P@10: 0.20699999999999988, AP: 0.1477009039803989}

# %%
from ir_measures import *
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('msmarco-distilbert-dot-v5')  # replace with your model

# %%
run = {}

for i, row in test_queries.iterrows():
    search_res = es.search(index=index_name, query=make_query(row['text_left']), size=20)['hits']
    run[str(row['id_left'])] = {}
                 
    for hit in search_res['hits']:
        run[str(row['id_left'])][hit['_id']] = hit['_score']

# %%
# q_ids = list(run.keys())

# run_rerank = {}

# for q_id in q_ids:
#     query_text = test_queries[test_queries['id_left']==int(q_id)]['text_left'].item()
#     query_embedding = model.encode(query_text)
#     run_rerank[q_id] = {}

#     docs_texts = []
#     for doc_id in run[str(q_id)]:
#         docs_texts.append(df[df['id_right']==int(doc_id)]['text_right'].item())
#     docs_embedding = model.encode(docs_texts)
        
#     if len(docs_embedding) == 0:
#         continue
#     cos_sim = util.dot_score(query_embedding, docs_embedding)[0]
#     for i, doc_id in enumerate(run[str(q_id)]):
#         run_rerank[q_id][doc_id] = cos_sim[i].item()

# %%
newRun = {}
otherDf = df.set_index('id_right')
for index, row in test_queries.iterrows():
    leftEncode = model.encode(row['text_left'])
    newRun[str(row['id_left'])] = {}
    
    searchResults = []
    for rightId in run[str(row['id_left'])]:
        searchResults.append(otherDf['text_right'][int(rightId)])
    rightEncode = model.encode(searchResults)

    if(len(searchResults) > 0):
        cos_sim = util.dot_score(leftEncode, rightEncode)[0]
        for innerIndex, innerRow in enumerate(run[str(row['id_left'])]):
            newRun[str(row['id_left'])][innerRow] = cos_sim[innerIndex].item()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Учеба\Назарбаев Университет\Masters\masters1Year\secondSem\InfoRetrieval\labs\lab.ipynb Cell 22 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/%D0%A3%D1%87%D0%B5%D0%B1%D0%B0/%D0%9D%D0%B0%D0%B7%D0%B0%D1%80%D0%B1%D0%B0%D0%B5%D0%B2%20%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/Masters/masters1Year/secondSem/InfoRetrieval/labs/lab.ipynb#X31sZmlsZQ%3D%3D?line=7'>8</a> for rightId in run[str(row['id_left'])]:
#       <a href='vscode-notebook-cell:/d%3A/%D0%A3%D1%87%D0%B5%D0%B1%D0%B0/%D0%9D%D0%B0%D0%B7%D0%B0%D1%80%D0%B1%D0%B0%D0%B5%D0%B2%20%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/Masters/masters1Year/secondSem/InfoRetrieval/labs/lab.ipynb#X31sZmlsZQ%3D%3D?line=8'>9</a>     searchResults.append(otherDf['text_right'][int(rightId)])
# ---> <a href='vscode-notebook-cell:/d%3A/%D0%A3%D1%87%D0%B5%D0%B1%D0%B0/%D0%9D%D0%B0%D0%B7%D0%B0%D1%80%D0%B1%D0%B0%D0%B5%D0%B2%20%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/Masters/masters1Year/secondSem/InfoRetrieval/labs/lab.ipynb#X31sZmlsZQ%3D%3D?line=9'>10</a> rightEncode = model.encode(searchResults)
#      <a href='vscode-notebook-cell:/d%3A/%D0%A3%D1%87%D0%B5%D0%B1%D0%B0/%D0%9D%D0%B0%D0%B7%D0%B0%D1%80%D0%B1%D0%B0%D0%B5%D0%B2%20%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/Masters/masters1Year/secondSem/InfoRetrieval/labs/lab.ipynb#X31sZmlsZQ%3D%3D?line=11'>12</a> if(len(searchResults) > 0):
#      <a href='vscode-notebook-cell:/d%3A/%D0%A3%D1%87%D0%B5%D0%B1%D0%B0/%D0%9D%D0%B0%D0%B7%D0%B0%D1%80%D0%B1%D0%B0%D0%B5%D0%B2%20%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/Masters/masters1Year/secondSem/InfoRetrieval/labs/lab.ipynb#X31sZmlsZQ%3D%3D?line=12'>13</a>     cos_sim = util.dot_score(leftEncode, rightEncode)[0]
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\sentence_transformers\SentenceTransformer.py:165, in SentenceTransformer.encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     162 features = batch_to_device(features, device)
#     164 with torch.no_grad():
# --> 165     out_features = self.forward(features)
#     167     if output_value == 'token_embeddings':
#     168         embeddings = []
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\sentence_transformers\models\Transformer.py:66, in Transformer.forward(self, features)
#      63 if 'token_type_ids' in features:
#      64     trans_features['token_type_ids'] = features['token_type_ids']
# ---> 66 output_states = self.auto_model(**trans_features, return_dict=False)
#      67 output_tokens = output_states[0]
#      69 features.update({'token_embeddings': output_tokens, 'attention_mask': features['attention_mask']})
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:583, in DistilBertModel.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     579 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     581 embeddings = self.embeddings(input_ids, inputs_embeds)  # (bs, seq_length, dim)
# --> 583 return self.transformer(
#     584     x=embeddings,
#     585     attn_mask=attention_mask,
#     586     head_mask=head_mask,
#     587     output_attentions=output_attentions,
#     588     output_hidden_states=output_hidden_states,
#     589     return_dict=return_dict,
#     590 )
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:359, in Transformer.forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     356 if output_hidden_states:
#     357     all_hidden_states = all_hidden_states + (hidden_state,)
# --> 359 layer_outputs = layer_module(
#     360     x=hidden_state, attn_mask=attn_mask, head_mask=head_mask[i], output_attentions=output_attentions
#     361 )
#     362 hidden_state = layer_outputs[-1]
#     364 if output_attentions:
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:313, in TransformerBlock.forward(self, x, attn_mask, head_mask, output_attentions)
#     310 sa_output = self.sa_layer_norm(sa_output + x)  # (bs, seq_length, dim)
#     312 # Feed Forward Network
# --> 313 ffn_output = self.ffn(sa_output)  # (bs, seq_length, dim)
#     314 ffn_output: torch.Tensor = self.output_layer_norm(ffn_output + sa_output)  # (bs, seq_length, dim)
#     316 output = (ffn_output,)
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:254, in FFN.forward(self, input)
#     253 def forward(self, input: torch.Tensor) -> torch.Tensor:
# --> 254     return apply_chunking_to_forward(self.ff_chunk, self.chunk_size_feed_forward, self.seq_len_dim, input)
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\pytorch_utils.py:248, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     245     # concatenate output at same dimension
#     246     return torch.cat(output_chunks, dim=chunk_dim)
# --> 248 return forward_fn(*input_tensors)
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:259, in FFN.ff_chunk(self, input)
#     257 x = self.lin1(input)
#     258 x = self.activation(x)
# --> 259 x = self.lin2(x)
#     260 x = self.dropout(x)
#     261 return x
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
qrels = ir_measures.read_trec_qrels('qrels')
print(newRun)
print(run)
ir_measures.calc_aggregate([P@10, P@20, MAP@20], qrels, newRun)
# Out:
# {158491: {'1880296': 75.81673431396484, '2261272': 70.7028579711914, '607552': 75.90214538574219, '1957435': 77.61271667480469, '625257': 72.64411926269531, '635537': 80.26268005371094, '1774491': 74.48651885986328, '663828': 72.2364273071289, '158491': 79.92601776123047, '1956922': 70.5085678100586, '1180246': 68.72467803955078, '1170039': 73.1563949584961, '589549': 71.44168853759766, '360918': 77.82566833496094, '945068': 69.86650085449219, '685181': 71.4924087524414, '2411344': 70.28116607666016, '1093529': 75.78836059570312, '1158969': 72.81409454345703, '742912': 77.2335205078125}, 5728: {'5728': 80.53766632080078, '1890681': 71.7760009765625, '283099': 75.02107238769531, '98452': 70.2144546508789, '592647': 73.87507629394531, '970793': 70.50012969970703, '375146': 71.57810974121094, '1597007': 70.98116302490234, '911906': 69.88957214355469, '501880': 66.70128631591797, '645822': 72.81500244140625, '255972': 71.07779693603516, '849904': 67.53150939941406, '79940': 68.79461669921875, '2184293': 72.07027435302734, '1750830': 65.6417236328125, '2250822': 68.3165283203125, '2149047': 68.70921325683594, '1893219': 66.39070892333984, '1404651': 69.25114440917969}, 13554: {'13554': 81.05690002441406, '1354099': 78.20568084716797, '166298': 82.50244140625, '1343180': 79.84637451171875, '506304': 77.6648178100586, '1355975': 76.79202270507812, '1333624': 78.22998046875, '1355603': 78.09849548339844, '2108477': 75.66120910644531, '2206256': 75.73452758789062, '2164978': 80.59315490722656, '2164385': 80.29227447509766, '1354324': 76.58570861816406, '1070': 78.86798095703125, '1604564': 75.48193359375, '1231923': 77.13699340820312, '1354754': 77.58731079101562, '1212060': 74.22966003417969, '1354456': 78.49520111083984, '107818': 77.30818939208984}, 32674: {'1317839': 76.0262222290039, '1378846': 77.73973083496094, '834604': 77.25464630126953, '784701': 78.28205871582031, '1505849': 76.41004943847656, '671380': 75.44462585449219, '968448': 78.98741149902344, '961758': 76.13256072998047, '958943': 68.00749206542969, '1415478': 71.51223754882812, '910449': 67.85256958007812, '484924': 67.35247802734375, '1205770': 70.30392456054688, '870643': 71.18986511230469, '1560729': 71.65217590332031, '1631': 67.42277526855469, '375161': 71.35456085205078, '1423812': 70.27332305908203, '1134226': 68.51715087890625, '693088': 70.34113311767578}, 406391: {'2186467': 78.66400146484375, '2328959': 75.26616668701172, '855680': 78.20872497558594, '1325717': 76.90328979492188, '40342': 73.3080825805664, '2264449': 70.47254180908203, '2002272': 67.48245239257812, '1789451': 63.11504364013672, '1248550': 70.87274169921875, '2382229': 66.75008392333984, '1712644': 68.53153991699219, '2244630': 66.26943969726562, '1931448': 66.68704223632812, '1828795': 69.1801528930664, '1512849': 65.37680053710938, '1085516': 71.06005859375, '2178317': 70.91398620605469, '1314997': 73.71556854248047, '1808681': 75.39221954345703, '87050': 76.31336975097656}, 5115: {'5115': 80.88204956054688, '1384004': 76.40424346923828, '897966': 72.985595703125, '481955': 73.10298919677734, '2270937': 71.39236450195312, '546166': 73.43730163574219, '419556': 74.28779602050781, '585361': 72.75934600830078, '1157462': 69.81058502197266, '549097': 71.25521850585938, '75643': 74.8590316772461, '807376': 71.71255493164062, '364605': 70.49862670898438, '242015': 70.07337951660156, '1196497': 72.25807189941406, '1337861': 72.30754089355469, '2216970': 69.5755844116211, '368170': 72.7474365234375, '246563': 70.9629135131836, '367546': 69.63876342773438}, 15469: {'1334817': 77.19124603271484, '2392139': 72.20783996582031, '15469': 81.99057006835938, '2149594': 76.74797058105469, '975904': 77.64277648925781, '2316444': 69.63949584960938, '939854': 70.6095962524414, '1533382': 75.7337646484375, '1234860': 77.1978759765625, '2102316': 73.48800659179688, '2413345': 73.54537963867188, '2069564': 78.62041473388672, '544571': 74.79594421386719, '1950839': 75.0281753540039, '1260341': 73.85105895996094 ...
# {'158491': {'1880296': 17.35782, '2261272': 17.199305, '607552': 17.118353, '1957435': 16.929768, '625257': 16.877832, '635537': 16.80612, '1774491': 16.570059, '663828': 16.55547, '158491': 16.063732, '1956922': 15.829921, '1180246': 15.605074, '1170039': 15.548958, '589549': 15.529997, '360918': 15.529997, '945068': 15.450452, '685181': 15.446558, '2411344': 15.212746, '1093529': 15.212746, '1158969': 15.212746, '742912': 15.137668}, '5728': {'5728': 17.517227, '1890681': 12.799604, '283099': 12.799604, '98452': 12.799604, '592647': 9.611742, '970793': 9.295022, '375146': 9.295022, '1597007': 9.295022, '911906': 9.295022, '501880': 9.295022, '645822': 9.295022, '255972': 9.295022, '849904': 9.295022, '79940': 9.295022, '2184293': 9.295022, '1750830': 9.295022, '2250822': 9.295022, '2149047': 9.295022, '1893219': 9.295022, '1404651': 9.295022}, '13554': {'13554': 20.214588, '1354099': 19.540907, '166298': 19.470991, '1343180': 19.35587, '506304': 18.851572, '1355975': 18.643457, '1333624': 18.503832, '1355603': 18.445082, '2108477': 18.419636, '2206256': 18.419153, '2164978': 18.394897, '2164385': 18.193438, '1354324': 18.11871, '1070': 18.043276, '1604564': 17.925966, '1231923': 17.760656, '1354754': 17.206886, '1212060': 17.081408, '1354456': 16.974325, '107818': 16.945627}, '32674': {'1317839': 27.759737, '1378846': 27.593052, '834604': 25.905182, '784701': 23.403019, '1505849': 22.52649, '671380': 22.52649, '968448': 22.207626, '961758': 21.910757, '958943': 19.52287, '1415478': 17.512783, '910449': 17.512783, '484924': 16.358646, '1205770': 16.358646, '870643': 16.358646, '1560729': 16.358646, '1631': 16.358646, '375161': 16.358646, '1423812': 16.358646, '1134226': 16.358646, '693088': 16.358646}, '406391': {'2186467': 22.439896, '2328959': 20.956043, '855680': 20.956043, '1325717': 19.520832, '40342': 17.541172, '2264449': 17.35907, '2002272': 16.787064, '1789451': 16.787064, '1248550': 16.787064, '2382229': 16.787064, '1712644': 16.787064, '2244630': 16.787064, '1931448': 16.787064, '1828795': 16.787064, '1512849': 16.787064, '1085516': 15.019711, '2178317': 15.019711, '1314997': 14.127245, '1808681': 14.031917, '87050': 13.92095}, '5115': {'5115': 25.938116, '1384004': 25.774609, '897966': 21.048279, '481955': 18.706472, '2270937': 15.285177, '546166': 15.285177, '419556': 9.146714, '585361': 8.975963, '1157462': 8.975963, '549097': 8.811469, '75643': 8.738676, '807376': 8.738676, '364605': 8.738676, '242015': 8.67407, '1196497': 8.652897, '1337861': 8.652897, '2216970': 8.652897, '368170': 8.56086, '246563': 8.550315, '367546': 8.550315}, '15469': {'1334817': 25.21299, '2392139': 24.842283, '15469': 24.842283, '2149594': 24.671633, '975904': 24.071684, '2316444': 24.060894, '939854': 23.955936, '1533382': 23.948826, '1234860': 23.837872, '2102316': 23.737326, '2413345': 23.737326, '2069564': 23.737326, '544571': 23.104006, '1950839': 22.965528, '1260341': 22.965528, '771772': 22.502945, '2365922': 22.47766, '841064': 22.381706, '2235862': 22.276466, '2405799': 22.276466}, '62953': {'62953': 20.81412, '252433': 20.059114, '62956': 18.071136, '1366881': 15.929525, '210440': 15.929525, '1193752': 14.695968, '62992': 13.962753, '1256265': 13.639729, '1354574': 13.639729, '289330': 13.434816, '524047': 12.534718, '1144930': 11.925493, '1013750': 11.925493, '1576707': 11.925493, '756070': 11.925493, '1184060': 11.925493, '956952': 11.925493, '2090336': 11.473871, '1335': 11.473871, '373568': 11.473871}, '152444': {'242736': 25.289124, '152444': 25.289124, '1120216': 24.727291, '247573': 23.596125, '128064': 22.070164, '1150937': 20.36021, '1225505': 20.36021, '289563': 19.015131, '569398': 17.135412, '376703': 17.135412, '2124613': 17.135412, '279748': 17.135412, '630058': 17.135412, '590437': 17.135412, '192182': 17.135412, '1647163': 17.135412, '2251234': 17.135412, '1417315': 15.947528, '1753570': 15.947528, '1120072': 15.78643}, '104086': {'104086': 16.286755, '1531009': 14.394924, '1464230': 14.394924, '1282288': 13.3 ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Учеба\Назарбаев Университет\Masters\masters1Year\secondSem\InfoRetrieval\labs\lab.ipynb Cell 23 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/d%3A/%D0%A3%D1%87%D0%B5%D0%B1%D0%B0/%D0%9D%D0%B0%D0%B7%D0%B0%D1%80%D0%B1%D0%B0%D0%B5%D0%B2%20%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/Masters/masters1Year/secondSem/InfoRetrieval/labs/lab.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> print(newRun)
#       <a href='vscode-notebook-cell:/d%3A/%D0%A3%D1%87%D0%B5%D0%B1%D0%B0/%D0%9D%D0%B0%D0%B7%D0%B0%D1%80%D0%B1%D0%B0%D0%B5%D0%B2%20%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/Masters/masters1Year/secondSem/InfoRetrieval/labs/lab.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a> print(run)
# ----> <a href='vscode-notebook-cell:/d%3A/%D0%A3%D1%87%D0%B5%D0%B1%D0%B0/%D0%9D%D0%B0%D0%B7%D0%B0%D1%80%D0%B1%D0%B0%D0%B5%D0%B2%20%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/Masters/masters1Year/secondSem/InfoRetrieval/labs/lab.ipynb#X32sZmlsZQ%3D%3D?line=3'>4</a> ir_measures.calc_aggregate([P@10, P@20, MAP@20], qrels, newRun)
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\ir_measures\providers\base.py:81, in Provider.calc_aggregate(self, measures, qrels, run)
#      80 def calc_aggregate(self, measures, qrels, run):
# ---> 81     return self.evaluator(measures, qrels).calc_aggregate(run)
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\ir_measures\providers\base.py:36, in Evaluator.calc_aggregate(self, run)
#      32 """
#      33 Returns aggregated measure values for this run.
#      34 """
#      35 aggregators = {m: m.aggregator() for m in self.measures}
# ---> 36 for metric in self.iter_calc(run):
#      37     aggregators[metric.measure].add(metric.value)
#      38 return {m: agg.result() for m, agg in aggregators.items()}
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\ir_measures\providers\base.py:22, in Evaluator.iter_calc(self, run)
#      18 """
#      19 Yields per-topic metrics this run.
#      20 """
#      21 expected_measure_qids = set(itertools.product(self.measures, self.qrel_qids))
# ---> 22 for metric in self._iter_calc(run):
#      23     expected_measure_qids.discard((metric.measure, metric.query_id))
#      24     yield metric
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\ir_measures\providers\pytrec_eval_provider.py:202, in PytrecEvalEvaluator._iter_calc(self, run)
#     200 run = ir_measures.util.RunConverter(run).as_dict_of_dict()
#     201 for invoker in self.invokers:
# --> 202     yield from invoker.iter_calc(run)
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\ir_measures\providers\pytrec_eval_provider.py:211, in PytrecEvalInvoker.iter_calc(self, run)
#     210 def iter_calc(self, run):
# --> 211     result = self.evaluator.evaluate(run)
#     212     for query_id, measures in result.items():
#     213         for measure_str, value in measures.items():
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\pytrec_eval\__init__.py:64, in RelevanceEvaluator.evaluate(self, scores)
#      62 if not scores:
#      63     return {}
# ---> 64 return super().evaluate(scores)
#
# TypeError: Unable to extract query/object scores.

# %%
# run = ir_measures.read_trec_run('search_with_stem.res')
qrels = ir_measures.read_trec_qrels('qrels')

ir_measures.calc_aggregate([P@10, P@20, AP], qrels, run)
# Out:
# {AP: 0.14701975024421418, P@10: 0.20699999999999988, P@20: 0.14750000000000008}
